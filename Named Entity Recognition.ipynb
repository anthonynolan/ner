# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import itertools
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('data/ner_dataset.csv')
train['Word'] = train['Word'].map(str.lower)
train.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
with open('data/penn_trebank.txt', 'tr') as f:
    content = f.readlines()

tidy = {}
for i in range(0, len(content)-1, 2):
    tidy[content[i].strip()] = content[i+1].strip()

# %%
tags_for_removal = set(train['POS'].values)- set(tidy.keys())
print(f'tags in training, but not in the original treebank set: {tags_for_removal}')
# Out:
# tags in training, but not in the original treebank set: {':', 'RRB', ',', ';', '.', 'LRB', '$', '``'}

# %%
# Decide on the features to determine the window size for training
input_data = []
for tup in train[['Word', 'POS', 'Tag']].itertuples(index = False, name=None):
    if tup[1] not in tags_for_removal:
        input_data.append(tup)
input_data[:20]
# Out:
# [('thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('london', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('british', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O')]

# %%
sequence_length = 3

matrix = []
for index in range(len(input_data)):
    if index+sequence_length>len(input_data):
        break
    matrix.append(input_data[index:index+sequence_length])
    index+=sequence_length

# %%
matrix
# Out:
# [[('thousands', 'NNS', 'O'), ('of', 'IN', 'O'), ('demonstrators', 'NNS', 'O')],
#  [('of', 'IN', 'O'), ('demonstrators', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('demonstrators', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('marched', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('marched', 'VBN', 'O'), ('through', 'IN', 'O')],
#  [('marched', 'VBN', 'O'), ('through', 'IN', 'O'), ('london', 'NNP', 'B-geo')],
#  [('through', 'IN', 'O'), ('london', 'NNP', 'B-geo'), ('to', 'TO', 'O')],
#  [('london', 'NNP', 'B-geo'), ('to', 'TO', 'O'), ('protest', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('protest', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('protest', 'VB', 'O'), ('the', 'DT', 'O'), ('war', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('war', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('war', 'NN', 'O'), ('in', 'IN', 'O'), ('iraq', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('iraq', 'NNP', 'B-geo'), ('and', 'CC', 'O')],
#  [('iraq', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('demand', 'VB', 'O')],
#  [('and', 'CC', 'O'), ('demand', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('demand', 'VB', 'O'), ('the', 'DT', 'O'), ('withdrawal', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('withdrawal', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('withdrawal', 'NN', 'O'), ('of', 'IN', 'O'), ('british', 'JJ', 'B-gpe')],
#  [('of', 'IN', 'O'), ('british', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O')],
#  [('british', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O'), ('from', 'IN', 'O')],
#  [('troops', 'NNS', 'O'), ('from', 'IN', 'O'), ('that', 'DT', 'O')],
#  [('from', 'IN', 'O'), ('that', 'DT', 'O'), ('country', 'NN', 'O')],
#  [('that', 'DT', 'O'), ('country', 'NN', 'O'), ('families', 'NNS', 'O')],
#  [('country', 'NN', 'O'), ('families', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('families', 'NNS', 'O'), ('of', 'IN', 'O'), ('soldiers', 'NNS', 'O')],
#  [('of', 'IN', 'O'), ('soldiers', 'NNS', 'O'), ('killed', 'VBN', 'O')],
#  [('soldiers', 'NNS', 'O'), ('killed', 'VBN', 'O'), ('in', 'IN', 'O')],
#  [('killed', 'VBN', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('conflict', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('conflict', 'NN', 'O'), ('joined', 'VBD', 'O')],
#  [('conflict', 'NN', 'O'), ('joined', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('joined', 'VBD', 'O'), ('the', 'DT', 'O'), ('protesters', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('protesters', 'NNS', 'O'), ('who', 'WP', 'O')],
#  [('protesters', 'NNS', 'O'), ('who', 'WP', 'O'), ('carried', 'VBD', 'O')],
#  [('who', 'WP', 'O'), ('carried', 'VBD', 'O'), ('banners', 'NNS', 'O')],
#  [('carried', 'VBD', 'O'), ('banners', 'NNS', 'O'), ('with', 'IN', 'O')],
#  [('banners', 'NNS', 'O'), ('with', 'IN', 'O'), ('such', 'JJ', 'O')],
#  [('with', 'IN', 'O'), ('such', 'JJ', 'O'), ('slogans', 'NNS', 'O')],
#  [('such', 'JJ', 'O'), ('slogans', 'NNS', 'O'), ('as', 'IN', 'O')],
#  [('slogans', 'NNS', 'O'), ('as', 'IN', 'O'), ('bush', 'NNP', 'B-per')],
#  [('as', 'IN', 'O'), ('bush', 'NNP', 'B-per'), ('number', 'NN', 'O')],
#  [('bush', 'NNP', 'B-per'), ('number', 'NN', 'O'), ('one', 'CD', 'O')],
#  [('number', 'NN', 'O'), ('one', 'CD', 'O'), ('terrorist', 'NN', 'O')],
#  [('one', 'CD', 'O'), ('terrorist', 'NN', 'O'), ('and', 'CC', 'O')],
#  [('terrorist', 'NN', 'O'), ('and', 'CC', 'O'), ('stop', 'VB', 'O')],
#  [('and', 'CC', 'O'), ('stop', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('stop', 'VB', 'O'), ('the', 'DT', 'O'), ('bombings', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('bombings', 'NNS', 'O'), ('they', 'PRP', 'O')],
#  [('bombings', 'NNS', 'O'), ('they', 'PRP', 'O'), ('marched', 'VBD', 'O')],
#  [('they', 'PRP', 'O'), ('marched', 'VBD', 'O'), ('from', 'IN', 'O')],
#  [('marched', 'VBD', 'O'), ('from', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('from', 'IN', 'O'), ('the', 'DT', 'O'), ('houses', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('houses', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('houses', 'NNS', 'O'), ('of', 'IN', 'O'), ('parliament', 'NN', 'O')],
#  [('of', 'IN', 'O'), ('parliament', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('parliament', 'NN', 'O'), ('to', 'TO', 'O'), ('a', 'DT', 'O')],
#  [('to', 'TO', 'O'), ('a', 'DT', 'O'), ('rally', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('rally', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('rally', 'NN', 'O'), ('in', 'IN', 'O'), ('hyde', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('hyde', 'NNP', 'B-geo'), ('park', 'NNP', 'I-geo')],
#  [('hyde', 'NNP', 'B-geo'), ('park', 'NNP', 'I-geo'), ('police', 'NNS', 'O')],
#  [('park', 'NNP', 'I-geo'), ('police', 'NNS', 'O'), ('put', 'VBD', 'O')],
#  [('police', 'NNS', 'O'), ('put', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('put', 'VBD', 'O'), ('the', 'DT', 'O'), ('number', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('number', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('number', 'NN', 'O'), ('of', 'IN', 'O'), ('marchers', 'NNS', 'O')],
#  [('of', 'IN', 'O'), ('marchers', 'NNS', 'O'), ('at', 'IN', 'O')],
#  [('marchers', 'NNS', 'O'), ('at', 'IN', 'O'), ('10,000', 'CD', 'O')],
#  [('at', 'IN', 'O'), ('10,000', 'CD', 'O'), ('while', 'IN', 'O')],
#  [('10,000', 'CD', 'O'), ('while', 'IN', 'O'), ('organizers', 'NNS', 'O')],
#  [('while', 'IN', 'O'), ('organizers', 'NNS', 'O'), ('claimed', 'VBD', 'O')],
#  [('organizers', 'NNS', 'O'), ('claimed', 'VBD', 'O'), ('it', 'PRP', 'O')],
#  [('claimed', 'VBD', 'O'), ('it', 'PRP', 'O'), ('was', 'VBD', 'O')],
#  [('it', 'PRP', 'O'), ('was', 'VBD', 'O'), ('1,00,000', 'CD', 'O')],
#  [('was', 'VBD', 'O'), ('1,00,000', 'CD', 'O'), ('the', 'DT', 'O')],
#  [('1,00,000', 'CD', 'O'), ('the', 'DT', 'O'), ('protest', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('protest', 'NN', 'O'), ('comes', 'VBZ', 'O')],
#  [('protest', 'NN', 'O'), ('comes', 'VBZ', 'O'), ('on', 'IN', 'O')],
#  [('comes', 'VBZ', 'O'), ('on', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('on', 'IN', 'O'), ('the', 'DT', 'O'), ('eve', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('eve', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('eve', 'NN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('annual', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('annual', 'JJ', 'O'), ('conference', 'NN', 'O')],
#  [('annual', 'JJ', 'O'), ('conference', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('conference', 'NN', 'O'), ('of', 'IN', 'O'), ('britain', 'NNP', 'B-geo')],
#  [('of', 'IN', 'O'), ('britain', 'NNP', 'B-geo'), ("'s", 'POS', 'O')],
#  [('britain', 'NNP', 'B-geo'), ("'s", 'POS', 'O'), ('ruling', 'VBG', 'O')],
#  [("'s", 'POS', 'O'), ('ruling', 'VBG', 'O'), ('labor', 'NNP', 'B-org')],
#  [('ruling', 'VBG', 'O'),
#   ('labor', 'NNP', 'B-org'),
#   ('party', 'NNP', 'I-org')],
#  [('labor', 'NNP', 'B-org'), ('party', 'NNP', 'I-org'), ('in', 'IN', 'O')],
#  [('party', 'NNP', 'I-org'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('southern', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('southern', 'JJ', 'O'), ('english', 'JJ', 'B-gpe')],
#  [('southern', 'JJ', 'O'), ('english', 'JJ', 'B-gpe'), ('seaside', 'NN', 'O')],
#  [('english', 'JJ', 'B-gpe'), ('seaside', 'NN', 'O'), ('resort', 'NN', 'O')],
#  [('seaside', 'NN', 'O'), ('resort', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('resort', 'NN', 'O'), ('of', 'IN', 'O'), ('brighton', 'NNP', 'B-geo')],
#  [('of', 'IN', 'O'), ('brighton', 'NNP', 'B-geo'), ('the', 'DT', 'O')],
#  [('brighton', 'NNP', 'B-geo'), ('the', 'DT', 'O'), ('party', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('party', 'NN', 'O'), ('is', 'VBZ', 'O')],
#  [('party', 'NN', 'O'), ('is', 'VBZ', 'O'), ('divided', 'VBN', 'O')],
#  [('is', 'VBZ', 'O'), ('divided', 'VBN', 'O'), ('over', 'IN', 'O')],
#  [('divided', 'VBN', 'O'), ('over', 'IN', 'O'), ('britain', 'NNP', 'B-gpe')],
#  [('over', 'IN', 'O'), ('britain', 'NNP', 'B-gpe'), ("'s", 'POS', 'O')],
#  [('britain', 'NNP', 'B-gpe'),
#   ("'s", 'POS', 'O'),
#   ('participation', 'NN', 'O')],
#  [("'s", 'POS', 'O'), ('participation', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('participation', 'NN', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('iraq', 'NNP', 'B-geo')],
#  [('the', 'DT', 'O'), ('iraq', 'NNP', 'B-geo'), ('conflict', 'NN', 'O')],
#  [('iraq', 'NNP', 'B-geo'), ('conflict', 'NN', 'O'), ('and', 'CC', 'O')],
#  [('conflict', 'NN', 'O'), ('and', 'CC', 'O'), ('the', 'DT', 'O')],
#  [('and', 'CC', 'O'), ('the', 'DT', 'O'), ('continued', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('continued', 'JJ', 'O'), ('deployment', 'NN', 'O')],
#  [('continued', 'JJ', 'O'), ('deployment', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('deployment', 'NN', 'O'), ('of', 'IN', 'O'), ('8,500', 'CD', 'O')],
#  [('of', 'IN', 'O'), ('8,500', 'CD', 'O'), ('british', 'JJ', 'B-gpe')],
#  [('8,500', 'CD', 'O'), ('british', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O')],
#  [('british', 'JJ', 'B-gpe'), ('troops', 'NNS', 'O'), ('in', 'IN', 'O')],
#  [('troops', 'NNS', 'O'), ('in', 'IN', 'O'), ('that', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('that', 'DT', 'O'), ('country', 'NN', 'O')],
#  [('that', 'DT', 'O'), ('country', 'NN', 'O'), ('the', 'DT', 'O')],
#  [('country', 'NN', 'O'), ('the', 'DT', 'O'), ('london', 'NNP', 'B-geo')],
#  [('the', 'DT', 'O'), ('london', 'NNP', 'B-geo'), ('march', 'NN', 'O')],
#  [('london', 'NNP', 'B-geo'), ('march', 'NN', 'O'), ('came', 'VBD', 'O')],
#  [('march', 'NN', 'O'), ('came', 'VBD', 'O'), ('ahead', 'RB', 'O')],
#  [('came', 'VBD', 'O'), ('ahead', 'RB', 'O'), ('of', 'IN', 'O')],
#  [('ahead', 'RB', 'O'), ('of', 'IN', 'O'), ('anti-war', 'JJ', 'O')],
#  [('of', 'IN', 'O'), ('anti-war', 'JJ', 'O'), ('protests', 'NNS', 'O')],
#  [('anti-war', 'JJ', 'O'), ('protests', 'NNS', 'O'), ('today', 'NN', 'O')],
#  [('protests', 'NNS', 'O'), ('today', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('today', 'NN', 'O'), ('in', 'IN', 'O'), ('other', 'JJ', 'O')],
#  [('in', 'IN', 'O'), ('other', 'JJ', 'O'), ('cities', 'NNS', 'O')],
#  [('other', 'JJ', 'O'), ('cities', 'NNS', 'O'), ('including', 'VBG', 'O')],
#  [('cities', 'NNS', 'O'), ('including', 'VBG', 'O'), ('rome', 'NNP', 'B-geo')],
#  [('including', 'VBG', 'O'),
#   ('rome', 'NNP', 'B-geo'),
#   ('paris', 'NNP', 'B-geo')],
#  [('rome', 'NNP', 'B-geo'), ('paris', 'NNP', 'B-geo'), ('and', 'CC', 'O')],
#  [('paris', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('madrid', 'NNP', 'B-geo')],
#  [('and', 'CC', 'O'), ('madrid', 'NNP', 'B-geo'), ('the', 'DT', 'O')],
#  [('madrid', 'NNP', 'B-geo'),
#   ('the', 'DT', 'O'),
#   ('international', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'),
#   ('international', 'NNP', 'B-org'),
#   ('atomic', 'NNP', 'I-org')],
#  [('international', 'NNP', 'B-org'),
#   ('atomic', 'NNP', 'I-org'),
#   ('energy', 'NNP', 'I-org')],
#  [('atomic', 'NNP', 'I-org'),
#   ('energy', 'NNP', 'I-org'),
#   ('agency', 'NNP', 'I-org')],
#  [('energy', 'NNP', 'I-org'), ('agency', 'NNP', 'I-org'), ('is', 'VBZ', 'O')],
#  [('agency', 'NNP', 'I-org'), ('is', 'VBZ', 'O'), ('to', 'TO', 'O')],
#  [('is', 'VBZ', 'O'), ('to', 'TO', 'O'), ('hold', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('hold', 'VB', 'O'), ('second', 'JJ', 'O')],
#  [('hold', 'VB', 'O'), ('second', 'JJ', 'O'), ('day', 'NN', 'O')],
#  [('second', 'JJ', 'O'), ('day', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('day', 'NN', 'O'), ('of', 'IN', 'O'), ('talks', 'NNS', 'O')],
#  [('of', 'IN', 'O'), ('talks', 'NNS', 'O'), ('in', 'IN', 'O')],
#  [('talks', 'NNS', 'O'), ('in', 'IN', 'O'), ('vienna', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'),
#   ('vienna', 'NNP', 'B-geo'),
#   ('wednesday', 'NNP', 'B-tim')],
#  [('vienna', 'NNP', 'B-geo'),
#   ('wednesday', 'NNP', 'B-tim'),
#   ('on', 'IN', 'O')],
#  [('wednesday', 'NNP', 'B-tim'), ('on', 'IN', 'O'), ('how', 'WRB', 'O')],
#  [('on', 'IN', 'O'), ('how', 'WRB', 'O'), ('to', 'TO', 'O')],
#  [('how', 'WRB', 'O'), ('to', 'TO', 'O'), ('respond', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('respond', 'VB', 'O'), ('to', 'TO', 'O')],
#  [('respond', 'VB', 'O'), ('to', 'TO', 'O'), ('iran', 'NNP', 'B-gpe')],
#  [('to', 'TO', 'O'), ('iran', 'NNP', 'B-gpe'), ("'s", 'POS', 'O')],
#  [('iran', 'NNP', 'B-gpe'), ("'s", 'POS', 'O'), ('resumption', 'NN', 'O')],
#  [("'s", 'POS', 'O'), ('resumption', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('resumption', 'NN', 'O'), ('of', 'IN', 'O'), ('low-level', 'JJ', 'O')],
#  [('of', 'IN', 'O'), ('low-level', 'JJ', 'O'), ('uranium', 'NN', 'O')],
#  [('low-level', 'JJ', 'O'), ('uranium', 'NN', 'O'), ('conversion', 'NN', 'O')],
#  [('uranium', 'NN', 'O'), ('conversion', 'NN', 'O'), ('iran', 'NNP', 'B-gpe')],
#  [('conversion', 'NN', 'O'), ('iran', 'NNP', 'B-gpe'), ('this', 'DT', 'O')],
#  [('iran', 'NNP', 'B-gpe'), ('this', 'DT', 'O'), ('week', 'NN', 'O')],
#  [('this', 'DT', 'O'), ('week', 'NN', 'O'), ('restarted', 'VBD', 'O')],
#  [('week', 'NN', 'O'), ('restarted', 'VBD', 'O'), ('parts', 'NNS', 'O')],
#  [('restarted', 'VBD', 'O'), ('parts', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('parts', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('conversion', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('conversion', 'NN', 'O'), ('process', 'NN', 'O')],
#  [('conversion', 'NN', 'O'), ('process', 'NN', 'O'), ('at', 'IN', 'O')],
#  [('process', 'NN', 'O'), ('at', 'IN', 'O'), ('its', 'PRP$', 'O')],
#  [('at', 'IN', 'O'), ('its', 'PRP$', 'O'), ('isfahan', 'NNP', 'B-geo')],
#  [('its', 'PRP$', 'O'), ('isfahan', 'NNP', 'B-geo'), ('nuclear', 'JJ', 'O')],
#  [('isfahan', 'NNP', 'B-geo'), ('nuclear', 'JJ', 'O'), ('plant', 'NN', 'O')],
#  [('nuclear', 'JJ', 'O'), ('plant', 'NN', 'O'), ('iranian', 'JJ', 'B-gpe')],
#  [('plant', 'NN', 'O'), ('iranian', 'JJ', 'B-gpe'), ('officials', 'NNS', 'O')],
#  [('iranian', 'JJ', 'B-gpe'), ('officials', 'NNS', 'O'), ('say', 'VBP', 'O')],
#  [('officials', 'NNS', 'O'), ('say', 'VBP', 'O'), ('they', 'PRP', 'O')],
#  [('say', 'VBP', 'O'), ('they', 'PRP', 'O'), ('expect', 'VBP', 'O')],
#  [('they', 'PRP', 'O'), ('expect', 'VBP', 'O'), ('to', 'TO', 'O')],
#  [('expect', 'VBP', 'O'), ('to', 'TO', 'O'), ('get', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('get', 'VB', 'O'), ('access', 'NN', 'O')],
#  [('get', 'VB', 'O'), ('access', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('access', 'NN', 'O'), ('to', 'TO', 'O'), ('sealed', 'JJ', 'O')],
#  [('to', 'TO', 'O'), ('sealed', 'JJ', 'O'), ('sensitive', 'JJ', 'O')],
#  [('sealed', 'JJ', 'O'), ('sensitive', 'JJ', 'O'), ('parts', 'NNS', 'O')],
#  [('sensitive', 'JJ', 'O'), ('parts', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('parts', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('plant', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('plant', 'NN', 'O'), ('wednesday', 'NNP', 'B-tim')],
#  [('plant', 'NN', 'O'), ('wednesday', 'NNP', 'B-tim'), ('after', 'IN', 'O')],
#  [('wednesday', 'NNP', 'B-tim'), ('after', 'IN', 'O'), ('an', 'DT', 'O')],
#  [('after', 'IN', 'O'), ('an', 'DT', 'O'), ('iaea', 'NNP', 'B-org')],
#  [('an', 'DT', 'O'), ('iaea', 'NNP', 'B-org'), ('surveillance', 'NN', 'O')],
#  [('iaea', 'NNP', 'B-org'),
#   ('surveillance', 'NN', 'O'),
#   ('system', 'NN', 'O')],
#  [('surveillance', 'NN', 'O'), ('system', 'NN', 'O'), ('begins', 'VBZ', 'O')],
#  [('system', 'NN', 'O'), ('begins', 'VBZ', 'O'), ('functioning', 'VBG', 'O')],
#  [('begins', 'VBZ', 'O'), ('functioning', 'VBG', 'O'), ('the', 'DT', 'O')],
#  [('functioning', 'VBG', 'O'), ('the', 'DT', 'O'), ('step', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('step', 'NN', 'O'), ('will', 'MD', 'O')],
#  [('step', 'NN', 'O'), ('will', 'MD', 'O'), ('allow', 'VB', 'O')],
#  [('will', 'MD', 'O'), ('allow', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('allow', 'VB', 'O'), ('the', 'DT', 'O'), ('facility', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('facility', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('facility', 'NN', 'O'), ('to', 'TO', 'O'), ('operate', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('operate', 'VB', 'O'), ('at', 'IN', 'O')],
#  [('operate', 'VB', 'O'), ('at', 'IN', 'O'), ('full', 'JJ', 'O')],
#  [('at', 'IN', 'O'), ('full', 'JJ', 'O'), ('capacity', 'NN', 'O')],
#  [('full', 'JJ', 'O'), ('capacity', 'NN', 'O'), ('the', 'DT', 'O')],
#  [('capacity', 'NN', 'O'), ('the', 'DT', 'O'), ('european', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('european', 'NNP', 'B-org'), ('union', 'NNP', 'I-org')],
#  [('european', 'NNP', 'B-org'),
#   ('union', 'NNP', 'I-org'),
#   ('with', 'IN', 'O')],
#  [('union', 'NNP', 'I-org'), ('with', 'IN', 'O'), ('u.s.', 'NNP', 'B-gpe')],
#  [('with', 'IN', 'O'), ('u.s.', 'NNP', 'B-gpe'), ('backing', 'NN', 'O')],
#  [('u.s.', 'NNP', 'B-gpe'), ('backing', 'NN', 'O'), ('has', 'VBZ', 'O')],
#  [('backing', 'NN', 'O'), ('has', 'VBZ', 'O'), ('threatened', 'VBN', 'O')],
#  [('has', 'VBZ', 'O'), ('threatened', 'VBN', 'O'), ('to', 'TO', 'O')],
#  [('threatened', 'VBN', 'O'), ('to', 'TO', 'O'), ('refer', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('refer', 'VB', 'O'), ('iran', 'NNP', 'B-gpe')],
#  [('refer', 'VB', 'O'), ('iran', 'NNP', 'B-gpe'), ('to', 'TO', 'O')],
#  [('iran', 'NNP', 'B-gpe'), ('to', 'TO', 'O'), ('the', 'DT', 'O')],
#  [('to', 'TO', 'O'), ('the', 'DT', 'O'), ('u.n.', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('u.n.', 'NNP', 'B-org'), ('security', 'NNP', 'I-org')],
#  [('u.n.', 'NNP', 'B-org'),
#   ('security', 'NNP', 'I-org'),
#   ('council', 'NNP', 'I-org')],
#  [('security', 'NNP', 'I-org'),
#   ('council', 'NNP', 'I-org'),
#   ('which', 'WDT', 'O')],
#  [('council', 'NNP', 'I-org'), ('which', 'WDT', 'O'), ('could', 'MD', 'O')],
#  [('which', 'WDT', 'O'), ('could', 'MD', 'O'), ('impose', 'VB', 'O')],
#  [('could', 'MD', 'O'), ('impose', 'VB', 'O'), ('sanctions', 'NNS', 'O')],
#  [('impose', 'VB', 'O'), ('sanctions', 'NNS', 'O'), ('if', 'IN', 'O')],
#  [('sanctions', 'NNS', 'O'), ('if', 'IN', 'O'), ('it', 'PRP', 'O')],
#  [('if', 'IN', 'O'), ('it', 'PRP', 'O'), ('finds', 'VBZ', 'O')],
#  [('it', 'PRP', 'O'), ('finds', 'VBZ', 'O'), ('tehran', 'NNP', 'B-gpe')],
#  [('finds', 'VBZ', 'O'), ('tehran', 'NNP', 'B-gpe'), ('has', 'VBZ', 'O')],
#  [('tehran', 'NNP', 'B-gpe'), ('has', 'VBZ', 'O'), ('violated', 'VBN', 'O')],
#  [('has', 'VBZ', 'O'), ('violated', 'VBN', 'O'), ('the', 'DT', 'O')],
#  [('violated', 'VBN', 'O'), ('the', 'DT', 'O'), ('nuclear', 'NNP', 'B-art')],
#  [('the', 'DT', 'O'),
#   ('nuclear', 'NNP', 'B-art'),
#   ('non-proliferation', 'NNP', 'I-art')],
#  [('nuclear', 'NNP', 'B-art'),
#   ('non-proliferation', 'NNP', 'I-art'),
#   ('treaty', 'NN', 'O')],
#  [('non-proliferation', 'NNP', 'I-art'),
#   ('treaty', 'NN', 'O'),
#   ('iran', 'NNP', 'B-gpe')],
#  [('treaty', 'NN', 'O'), ('iran', 'NNP', 'B-gpe'), ("'s", 'POS', 'O')],
#  [('iran', 'NNP', 'B-gpe'), ("'s", 'POS', 'O'), ('new', 'JJ', 'O')],
#  [("'s", 'POS', 'O'), ('new', 'JJ', 'O'), ('president', 'NNP', 'B-per')],
#  [('new', 'JJ', 'O'),
#   ('president', 'NNP', 'B-per'),
#   ('mahmoud', 'NNP', 'I-per')],
#  [('president', 'NNP', 'B-per'),
#   ('mahmoud', 'NNP', 'I-per'),
#   ('ahmadinejad', 'NNP', 'I-per')],
#  [('mahmoud', 'NNP', 'I-per'),
#   ('ahmadinejad', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O')],
#  [('ahmadinejad', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('tuesday', 'NNP', 'B-tim')],
#  [('said', 'VBD', 'O'), ('tuesday', 'NNP', 'B-tim'), ('that', 'IN', 'O')],
#  [('tuesday', 'NNP', 'B-tim'),
#   ('that', 'IN', 'O'),
#   ('european', 'JJ', 'B-gpe')],
#  [('that', 'IN', 'O'),
#   ('european', 'JJ', 'B-gpe'),
#   ('incentives', 'NNS', 'O')],
#  [('european', 'JJ', 'B-gpe'),
#   ('incentives', 'NNS', 'O'),
#   ('aimed', 'VBN', 'O')],
#  [('incentives', 'NNS', 'O'), ('aimed', 'VBN', 'O'), ('at', 'IN', 'O')],
#  [('aimed', 'VBN', 'O'), ('at', 'IN', 'O'), ('persuading', 'VBG', 'O')],
#  [('at', 'IN', 'O'), ('persuading', 'VBG', 'O'), ('iran', 'NNP', 'B-gpe')],
#  [('persuading', 'VBG', 'O'), ('iran', 'NNP', 'B-gpe'), ('to', 'TO', 'O')],
#  [('iran', 'NNP', 'B-gpe'), ('to', 'TO', 'O'), ('end', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('end', 'VB', 'O'), ('its', 'PRP$', 'O')],
#  [('end', 'VB', 'O'), ('its', 'PRP$', 'O'), ('nuclear', 'JJ', 'O')],
#  [('its', 'PRP$', 'O'), ('nuclear', 'JJ', 'O'), ('fuel', 'NN', 'O')],
#  [('nuclear', 'JJ', 'O'), ('fuel', 'NN', 'O'), ('program', 'NN', 'O')],
#  [('fuel', 'NN', 'O'), ('program', 'NN', 'O'), ('are', 'VBP', 'O')],
#  [('program', 'NN', 'O'), ('are', 'VBP', 'O'), ('an', 'DT', 'O')],
#  [('are', 'VBP', 'O'), ('an', 'DT', 'O'), ('insult', 'NN', 'O')],
#  [('an', 'DT', 'O'), ('insult', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('insult', 'NN', 'O'), ('to', 'TO', 'O'), ('the', 'DT', 'O')],
#  [('to', 'TO', 'O'), ('the', 'DT', 'O'), ('iranian', 'JJ', 'B-gpe')],
#  [('the', 'DT', 'O'), ('iranian', 'JJ', 'B-gpe'), ('nation', 'NN', 'O')],
#  [('iranian', 'JJ', 'B-gpe'), ('nation', 'NN', 'O'), ('two', 'CD', 'O')],
#  [('nation', 'NN', 'O'), ('two', 'CD', 'O'), ('germans', 'NNS', 'B-gpe')],
#  [('two', 'CD', 'O'), ('germans', 'NNS', 'B-gpe'), ('and', 'CC', 'O')],
#  [('germans', 'NNS', 'B-gpe'), ('and', 'CC', 'O'), ('four', 'CD', 'O')],
#  [('and', 'CC', 'O'), ('four', 'CD', 'O'), ('nigerian', 'JJ', 'B-gpe')],
#  [('four', 'CD', 'O'), ('nigerian', 'JJ', 'B-gpe'), ('oil', 'NN', 'O')],
#  [('nigerian', 'JJ', 'B-gpe'), ('oil', 'NN', 'O'), ('workers', 'NNS', 'O')],
#  [('oil', 'NN', 'O'), ('workers', 'NNS', 'O'), ('were', 'VBD', 'O')],
#  [('workers', 'NNS', 'O'), ('were', 'VBD', 'O'), ('kidnapped', 'VBN', 'O')],
#  [('were', 'VBD', 'O'), ('kidnapped', 'VBN', 'O'), ('by', 'IN', 'O')],
#  [('kidnapped', 'VBN', 'O'), ('by', 'IN', 'O'), ('armed', 'JJ', 'O')],
#  [('by', 'IN', 'O'), ('armed', 'JJ', 'O'), ('militants', 'NNS', 'O')],
#  [('armed', 'JJ', 'O'), ('militants', 'NNS', 'O'), ('during', 'IN', 'O')],
#  [('militants', 'NNS', 'O'), ('during', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('during', 'IN', 'O'), ('a', 'DT', 'O'), ('raid', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('raid', 'NN', 'O'), ('on', 'IN', 'O')],
#  [('raid', 'NN', 'O'), ('on', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('on', 'IN', 'O'), ('a', 'DT', 'O'), ('boat', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('boat', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('boat', 'NN', 'O'), ('in', 'IN', 'O'), ('nigeria', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('nigeria', 'NNP', 'B-geo'), ("'s", 'POS', 'O')],
#  [('nigeria', 'NNP', 'B-geo'), ("'s", 'POS', 'O'), ('southern', 'JJ', 'O')],
#  [("'s", 'POS', 'O'), ('southern', 'JJ', 'O'), ('oil-rich', 'JJ', 'O')],
#  [('southern', 'JJ', 'O'), ('oil-rich', 'JJ', 'O'), ('delta', 'NNP', 'B-geo')],
#  [('oil-rich', 'JJ', 'O'), ('delta', 'NNP', 'B-geo'), ('region', 'NN', 'O')],
#  [('delta', 'NNP', 'B-geo'), ('region', 'NN', 'O'), ('an', 'DT', 'O')],
#  [('region', 'NN', 'O'), ('an', 'DT', 'O'), ('official', 'NN', 'O')],
#  [('an', 'DT', 'O'), ('official', 'NN', 'O'), ('with', 'IN', 'O')],
#  [('official', 'NN', 'O'), ('with', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('with', 'IN', 'O'), ('the', 'DT', 'O'), ('german', 'JJ', 'B-gpe')],
#  [('the', 'DT', 'O'), ('german', 'JJ', 'B-gpe'), ('firm', 'NN', 'O')],
#  [('german', 'JJ', 'B-gpe'),
#   ('firm', 'NN', 'O'),
#   ('bilfinger', 'NNP', 'B-org')],
#  [('firm', 'NN', 'O'),
#   ('bilfinger', 'NNP', 'B-org'),
#   ('berger', 'NNP', 'I-org')],
#  [('bilfinger', 'NNP', 'B-org'),
#   ('berger', 'NNP', 'I-org'),
#   ('thomas', 'NNP', 'B-per')],
#  [('berger', 'NNP', 'I-org'),
#   ('thomas', 'NNP', 'B-per'),
#   ('horbach', 'NNP', 'I-per')],
#  [('thomas', 'NNP', 'B-per'),
#   ('horbach', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O')],
#  [('horbach', 'NNP', 'I-per'), ('said', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('said', 'VBD', 'O'), ('the', 'DT', 'O'), ('gunmen', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('gunmen', 'NNS', 'O'), ('stopped', 'VBD', 'O')],
#  [('gunmen', 'NNS', 'O'), ('stopped', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('stopped', 'VBD', 'O'), ('the', 'DT', 'O'), ('supply', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('supply', 'NN', 'O'), ('boat', 'NN', 'O')],
#  [('supply', 'NN', 'O'), ('boat', 'NN', 'O'), ('wednesday', 'NNP', 'B-tim')],
#  [('boat', 'NN', 'O'), ('wednesday', 'NNP', 'B-tim'), ('as', 'IN', 'O')],
#  [('wednesday', 'NNP', 'B-tim'), ('as', 'IN', 'O'), ('it', 'PRP', 'O')],
#  [('as', 'IN', 'O'), ('it', 'PRP', 'O'), ('sailed', 'VBD', 'O')],
#  [('it', 'PRP', 'O'), ('sailed', 'VBD', 'O'), ('from', 'IN', 'O')],
#  [('sailed', 'VBD', 'O'), ('from', 'IN', 'O'), ('delta', 'NNP', 'B-geo')],
#  [('from', 'IN', 'O'), ('delta', 'NNP', 'B-geo'), ('state', 'NNP', 'I-geo')],
#  [('delta', 'NNP', 'B-geo'), ('state', 'NNP', 'I-geo'), ('to', 'TO', 'O')],
#  [('state', 'NNP', 'I-geo'), ('to', 'TO', 'O'), ('bayelsa', 'NNP', 'B-geo')],
#  [('to', 'TO', 'O'), ('bayelsa', 'NNP', 'B-geo'), ('state', 'NNP', 'I-geo')],
#  [('bayelsa', 'NNP', 'B-geo'), ('state', 'NNP', 'I-geo'), ('to', 'TO', 'O')],
#  [('state', 'NNP', 'I-geo'), ('to', 'TO', 'O'), ('inspect', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('inspect', 'VB', 'O'), ('an', 'DT', 'O')],
#  [('inspect', 'VB', 'O'), ('an', 'DT', 'O'), ('offshore', 'JJ', 'O')],
#  [('an', 'DT', 'O'), ('offshore', 'JJ', 'O'), ('oil', 'NN', 'O')],
#  [('offshore', 'JJ', 'O'), ('oil', 'NN', 'O'), ('field', 'NN', 'O')],
#  [('oil', 'NN', 'O'), ('field', 'NN', 'O'), ('owned', 'VBN', 'O')],
#  [('field', 'NN', 'O'), ('owned', 'VBN', 'O'), ('by', 'IN', 'O')],
#  [('owned', 'VBN', 'O'), ('by', 'IN', 'O'), ('royal-dutch', 'NNP', 'B-org')],
#  [('by', 'IN', 'O'),
#   ('royal-dutch', 'NNP', 'B-org'),
#   ('shell', 'NNP', 'I-org')],
#  [('royal-dutch', 'NNP', 'B-org'),
#   ('shell', 'NNP', 'I-org'),
#   ('the', 'DT', 'O')],
#  [('shell', 'NNP', 'I-org'), ('the', 'DT', 'O'), ('german', 'JJ', 'B-gpe')],
#  [('the', 'DT', 'O'), ('german', 'JJ', 'B-gpe'), ('firm', 'NN', 'O')],
#  [('german', 'JJ', 'B-gpe'), ('firm', 'NN', 'O'), ('works', 'VBZ', 'O')],
#  [('firm', 'NN', 'O'), ('works', 'VBZ', 'O'), ('as', 'IN', 'O')],
#  [('works', 'VBZ', 'O'), ('as', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('as', 'IN', 'O'), ('a', 'DT', 'O'), ('sub-contractor', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('sub-contractor', 'NN', 'O'), ('for', 'IN', 'O')],
#  [('sub-contractor', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('shell', 'NNP', 'B-org')],
#  [('for', 'IN', 'O'), ('shell', 'NNP', 'B-org'), ('militant', 'JJ', 'O')],
#  [('shell', 'NNP', 'B-org'), ('militant', 'JJ', 'O'), ('groups', 'NNS', 'O')],
#  [('militant', 'JJ', 'O'), ('groups', 'NNS', 'O'), ('frequently', 'RB', 'O')],
#  [('groups', 'NNS', 'O'), ('frequently', 'RB', 'O'), ('attack', 'VBP', 'O')],
#  [('frequently', 'RB', 'O'), ('attack', 'VBP', 'O'), ('oil', 'NN', 'O')],
#  [('attack', 'VBP', 'O'), ('oil', 'NN', 'O'), ('operations', 'NNS', 'O')],
#  [('oil', 'NN', 'O'), ('operations', 'NNS', 'O'), ('in', 'IN', 'O')],
#  [('operations', 'NNS', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('niger', 'NNP', 'B-geo')],
#  [('the', 'DT', 'O'), ('niger', 'NNP', 'B-geo'), ('delta', 'NNP', 'I-geo')],
#  [('niger', 'NNP', 'B-geo'), ('delta', 'NNP', 'I-geo'), ('to', 'TO', 'O')],
#  [('delta', 'NNP', 'I-geo'), ('to', 'TO', 'O'), ('demand', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('demand', 'VB', 'O'), ('social', 'JJ', 'O')],
#  [('demand', 'VB', 'O'), ('social', 'JJ', 'O'), ('services', 'NNS', 'O')],
#  [('social', 'JJ', 'O'), ('services', 'NNS', 'O'), ('and', 'CC', 'O')],
#  [('services', 'NNS', 'O'), ('and', 'CC', 'O'), ('better', 'JJR', 'O')],
#  [('and', 'CC', 'O'), ('better', 'JJR', 'O'), ('job', 'NN', 'O')],
#  [('better', 'JJR', 'O'), ('job', 'NN', 'O'), ('opportunities', 'NNS', 'O')],
#  [('job', 'NN', 'O'), ('opportunities', 'NNS', 'O'), ('from', 'IN', 'O')],
#  [('opportunities', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('multinational', 'JJ', 'O')],
#  [('from', 'IN', 'O'),
#   ('multinational', 'JJ', 'O'),
#   ('companies', 'NNS', 'O')],
#  [('multinational', 'JJ', 'O'),
#   ('companies', 'NNS', 'O'),
#   ('poor', 'JJ', 'O')],
#  [('companies', 'NNS', 'O'), ('poor', 'JJ', 'O'), ('residents', 'NNS', 'O')],
#  [('poor', 'JJ', 'O'), ('residents', 'NNS', 'O'), ('often', 'RB', 'O')],
#  [('residents', 'NNS', 'O'), ('often', 'RB', 'O'), ('complain', 'VBP', 'O')],
#  [('often', 'RB', 'O'), ('complain', 'VBP', 'O'), ('they', 'PRP', 'O')],
#  [('complain', 'VBP', 'O'), ('they', 'PRP', 'O'), ('have', 'VBP', 'O')],
#  [('they', 'PRP', 'O'), ('have', 'VBP', 'O'), ('been', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('been', 'VBN', 'O'), ('cheated', 'VBN', 'O')],
#  [('been', 'VBN', 'O'), ('cheated', 'VBN', 'O'), ('out', 'IN', 'O')],
#  [('cheated', 'VBN', 'O'), ('out', 'IN', 'O'), ('of', 'IN', 'O')],
#  [('out', 'IN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('huge', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('huge', 'JJ', 'O'), ('riches', 'NNS', 'O')],
#  [('huge', 'JJ', 'O'), ('riches', 'NNS', 'O'), ('extracted', 'VBN', 'O')],
#  [('riches', 'NNS', 'O'), ('extracted', 'VBN', 'O'), ('from', 'IN', 'O')],
#  [('extracted', 'VBN', 'O'), ('from', 'IN', 'O'), ('their', 'PRP$', 'O')],
#  [('from', 'IN', 'O'), ('their', 'PRP$', 'O'), ('tribal', 'JJ', 'O')],
#  [('their', 'PRP$', 'O'), ('tribal', 'JJ', 'O'), ('lands', 'NNS', 'O')],
#  [('tribal', 'JJ', 'O'), ('lands', 'NNS', 'O'), ('where', 'WRB', 'O')],
#  [('lands', 'NNS', 'O'), ('where', 'WRB', 'O'), ('the', 'DT', 'O')],
#  [('where', 'WRB', 'O'), ('the', 'DT', 'O'), ('bulk', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('bulk', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('bulk', 'NN', 'O'), ('of', 'IN', 'O'), ('nigeria', 'NNP', 'B-gpe')],
#  [('of', 'IN', 'O'), ('nigeria', 'NNP', 'B-gpe'), ("'s", 'POS', 'O')],
#  [('nigeria', 'NNP', 'B-gpe'), ("'s", 'POS', 'O'), ('2.3', 'CD', 'O')],
#  [("'s", 'POS', 'O'), ('2.3', 'CD', 'O'), ('million', 'CD', 'O')],
#  [('2.3', 'CD', 'O'), ('million', 'CD', 'O'), ('barrels', 'NNS', 'O')],
#  [('million', 'CD', 'O'), ('barrels', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('barrels', 'NNS', 'O'), ('of', 'IN', 'O'), ('petroleum', 'NN', 'O')],
#  [('of', 'IN', 'O'), ('petroleum', 'NN', 'O'), ('are', 'VBP', 'O')],
#  [('petroleum', 'NN', 'O'), ('are', 'VBP', 'O'), ('pumped', 'VBN', 'O')],
#  [('are', 'VBP', 'O'), ('pumped', 'VBN', 'O'), ('daily', 'RB', 'O')],
#  [('pumped', 'VBN', 'O'), ('daily', 'RB', 'O'), ('suspected', 'JJ', 'O')],
#  [('daily', 'RB', 'O'), ('suspected', 'JJ', 'O'), ('islamist', 'JJ', 'O')],
#  [('suspected', 'JJ', 'O'), ('islamist', 'JJ', 'O'), ('rebels', 'NNS', 'O')],
#  [('islamist', 'JJ', 'O'), ('rebels', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('rebels', 'NNS', 'O'), ('have', 'VBP', 'O'), ('fired', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('fired', 'VBN', 'O'), ('mortar', 'NN', 'O')],
#  [('fired', 'VBN', 'O'), ('mortar', 'NN', 'O'), ('shells', 'NNS', 'O')],
#  [('mortar', 'NN', 'O'), ('shells', 'NNS', 'O'), ('at', 'IN', 'O')],
#  [('shells', 'NNS', 'O'), ('at', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('at', 'IN', 'O'), ('the', 'DT', 'O'), ('palace', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('palace', 'NN', 'O'), ('used', 'VBN', 'O')],
#  [('palace', 'NN', 'O'), ('used', 'VBN', 'O'), ('by', 'IN', 'O')],
#  [('used', 'VBN', 'O'), ('by', 'IN', 'O'), ('somalia', 'NNP', 'B-geo')],
#  [('by', 'IN', 'O'), ('somalia', 'NNP', 'B-geo'), ("'s", 'POS', 'O')],
#  [('somalia', 'NNP', 'B-geo'), ("'s", 'POS', 'O'), ('interim', 'JJ', 'O')],
#  [("'s", 'POS', 'O'), ('interim', 'JJ', 'O'), ('president', 'NNP', 'B-per')],
#  [('interim', 'JJ', 'O'),
#   ('president', 'NNP', 'B-per'),
#   ('abdullahi', 'NNP', 'I-per')],
#  [('president', 'NNP', 'B-per'),
#   ('abdullahi', 'NNP', 'I-per'),
#   ('yusuf', 'NNP', 'I-per')],
#  [('abdullahi', 'NNP', 'I-per'),
#   ('yusuf', 'NNP', 'I-per'),
#   ('ahmad', 'NNP', 'I-per')],
#  [('yusuf', 'NNP', 'I-per'), ('ahmad', 'NNP', 'I-per'), ('it', 'PRP', 'O')],
#  [('ahmad', 'NNP', 'I-per'), ('it', 'PRP', 'O'), ('was', 'VBD', 'O')],
#  [('it', 'PRP', 'O'), ('was', 'VBD', 'O'), ('not', 'RB', 'O')],
#  [('was', 'VBD', 'O'), ('not', 'RB', 'O'), ('immediately', 'RB', 'O')],
#  [('not', 'RB', 'O'), ('immediately', 'RB', 'O'), ('clear', 'JJ', 'O')],
#  [('immediately', 'RB', 'O'), ('clear', 'JJ', 'O'), ('if', 'IN', 'O')],
#  [('clear', 'JJ', 'O'), ('if', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('if', 'IN', 'O'), ('the', 'DT', 'O'), ('president', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('president', 'NN', 'O'), ('was', 'VBD', 'O')],
#  [('president', 'NN', 'O'), ('was', 'VBD', 'O'), ('in', 'IN', 'O')],
#  [('was', 'VBD', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('palace', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('palace', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('palace', 'NN', 'O'), ('in', 'IN', 'O'), ('mogadishu', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('mogadishu', 'NNP', 'B-geo'), ('when', 'WRB', 'O')],
#  [('mogadishu', 'NNP', 'B-geo'), ('when', 'WRB', 'O'), ('the', 'DT', 'O')],
#  [('when', 'WRB', 'O'), ('the', 'DT', 'O'), ('attack', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('attack', 'NN', 'O'), ('occurred', 'VBD', 'O')],
#  [('attack', 'NN', 'O'), ('occurred', 'VBD', 'O'), ('or', 'CC', 'O')],
#  [('occurred', 'VBD', 'O'), ('or', 'CC', 'O'), ('if', 'IN', 'O')],
#  [('or', 'CC', 'O'), ('if', 'IN', 'O'), ('anyone', 'DT', 'O')],
#  [('if', 'IN', 'O'), ('anyone', 'DT', 'O'), ('was', 'VBD', 'O')],
#  [('anyone', 'DT', 'O'), ('was', 'VBD', 'O'), ('hurt', 'VBN', 'O')],
#  [('was', 'VBD', 'O'), ('hurt', 'VBN', 'O'), ('local', 'JJ', 'O')],
#  [('hurt', 'VBN', 'O'), ('local', 'JJ', 'O'), ('news', 'NN', 'O')],
#  [('local', 'JJ', 'O'), ('news', 'NN', 'O'), ('reports', 'NNS', 'O')],
#  [('news', 'NN', 'O'), ('reports', 'NNS', 'O'), ('said', 'VBD', 'O')],
#  [('reports', 'NNS', 'O'), ('said', 'VBD', 'O'), ('at', 'IN', 'O')],
#  [('said', 'VBD', 'O'), ('at', 'IN', 'O'), ('least', 'JJS', 'O')],
#  [('at', 'IN', 'O'), ('least', 'JJS', 'O'), ('five', 'CD', 'O')],
#  [('least', 'JJS', 'O'), ('five', 'CD', 'O'), ('mortar', 'NN', 'O')],
#  [('five', 'CD', 'O'), ('mortar', 'NN', 'O'), ('shells', 'NNS', 'O')],
#  [('mortar', 'NN', 'O'), ('shells', 'NNS', 'O'), ('hit', 'VBD', 'O')],
#  [('shells', 'NNS', 'O'), ('hit', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('hit', 'VBD', 'O'), ('the', 'DT', 'O'), ('palace', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('palace', 'NN', 'O'), ('compound', 'NN', 'O')],
#  [('palace', 'NN', 'O'), ('compound', 'NN', 'O'), ('and', 'CC', 'O')],
#  [('compound', 'NN', 'O'), ('and', 'CC', 'O'), ('other', 'JJ', 'O')],
#  [('and', 'CC', 'O'), ('other', 'JJ', 'O'), ('mortars', 'NNS', 'O')],
#  [('other', 'JJ', 'O'), ('mortars', 'NNS', 'O'), ('were', 'VBD', 'O')],
#  [('mortars', 'NNS', 'O'), ('were', 'VBD', 'O'), ('fired', 'VBN', 'O')],
#  [('were', 'VBD', 'O'), ('fired', 'VBN', 'O'), ('elsewhere', 'RB', 'O')],
#  [('fired', 'VBN', 'O'), ('elsewhere', 'RB', 'O'), ('in', 'IN', 'O')],
#  [('elsewhere', 'RB', 'O'), ('in', 'IN', 'O'), ('mogadishu', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'),
#   ('mogadishu', 'NNP', 'B-geo'),
#   ('wednesday', 'NNP', 'B-tim')],
#  [('mogadishu', 'NNP', 'B-geo'),
#   ('wednesday', 'NNP', 'B-tim'),
#   ('the', 'DT', 'O')],
#  [('wednesday', 'NNP', 'B-tim'), ('the', 'DT', 'O'), ('attacks', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('attacks', 'NNS', 'O'), ('occurred', 'VBD', 'O')],
#  [('attacks', 'NNS', 'O'), ('occurred', 'VBD', 'O'), ('after', 'IN', 'O')],
#  [('occurred', 'VBD', 'O'), ('after', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('after', 'IN', 'O'), ('the', 'DT', 'O'), ('government', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('government', 'NN', 'O'), ('said', 'VBD', 'O')],
#  [('government', 'NN', 'O'), ('said', 'VBD', 'O'), ('it', 'PRP', 'O')],
#  [('said', 'VBD', 'O'), ('it', 'PRP', 'O'), ('will', 'MD', 'O')],
#  [('it', 'PRP', 'O'), ('will', 'MD', 'O'), ('go', 'VB', 'O')],
#  [('will', 'MD', 'O'), ('go', 'VB', 'O'), ('ahead', 'RB', 'O')],
#  [('go', 'VB', 'O'), ('ahead', 'RB', 'O'), ('with', 'IN', 'O')],
#  [('ahead', 'RB', 'O'), ('with', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('with', 'IN', 'O'), ('a', 'DT', 'O'), ('reconciliation', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('reconciliation', 'NN', 'O'), ('conference', 'NN', 'O')],
#  [('reconciliation', 'NN', 'O'), ('conference', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('conference', 'NN', 'O'), ('to', 'TO', 'O'), ('which', 'WDT', 'O')],
#  [('to', 'TO', 'O'), ('which', 'WDT', 'O'), ('more', 'JJR', 'O')],
#  [('which', 'WDT', 'O'), ('more', 'JJR', 'O'), ('than', 'IN', 'O')],
#  [('more', 'JJR', 'O'), ('than', 'IN', 'O'), ('1,300', 'CD', 'O')],
#  [('than', 'IN', 'O'), ('1,300', 'CD', 'O'), ('somali', 'JJ', 'B-gpe')],
#  [('1,300', 'CD', 'O'), ('somali', 'JJ', 'B-gpe'), ('elders', 'NNS', 'O')],
#  [('somali', 'JJ', 'B-gpe'), ('elders', 'NNS', 'O'), ('warlords', 'NNS', 'O')],
#  [('elders', 'NNS', 'O'), ('warlords', 'NNS', 'O'), ('and', 'CC', 'O')],
#  [('warlords', 'NNS', 'O'), ('and', 'CC', 'O'), ('politicians', 'NNS', 'O')],
#  [('and', 'CC', 'O'), ('politicians', 'NNS', 'O'), ('are', 'VBP', 'O')],
#  [('politicians', 'NNS', 'O'), ('are', 'VBP', 'O'), ('invited', 'VBN', 'O')],
#  [('are', 'VBP', 'O'), ('invited', 'VBN', 'O'), ('iraqi', 'JJ', 'B-gpe')],
#  [('invited', 'VBN', 'O'), ('iraqi', 'JJ', 'B-gpe'), ('military', 'JJ', 'O')],
#  [('iraqi', 'JJ', 'B-gpe'),
#   ('military', 'JJ', 'O'),
#   ('officials', 'NNS', 'O')],
#  [('military', 'JJ', 'O'), ('officials', 'NNS', 'O'), ('say', 'VBP', 'O')],
#  [('officials', 'NNS', 'O'), ('say', 'VBP', 'O'), ('tanks', 'NNS', 'O')],
#  [('say', 'VBP', 'O'), ('tanks', 'NNS', 'O'), ('and', 'CC', 'O')],
#  [('tanks', 'NNS', 'O'), ('and', 'CC', 'O'), ('troops', 'NNS', 'O')],
#  [('and', 'CC', 'O'), ('troops', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('troops', 'NNS', 'O'), ('have', 'VBP', 'O'), ('arrived', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('arrived', 'VBN', 'O'), ('in', 'IN', 'O')],
#  [('arrived', 'VBN', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('northern', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('northern', 'JJ', 'O'), ('city', 'NN', 'O')],
#  [('northern', 'JJ', 'O'), ('city', 'NN', 'O'), ('mosul', 'NNP', 'B-geo')],
#  [('city', 'NN', 'O'), ('mosul', 'NNP', 'B-geo'), ('for', 'IN', 'O')],
#  [('mosul', 'NNP', 'B-geo'), ('for', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('for', 'IN', 'O'), ('a', 'DT', 'O'), ('new', 'JJ', 'O')],
#  [('a', 'DT', 'O'), ('new', 'JJ', 'O'), ('offensive', 'NN', 'O')],
#  [('new', 'JJ', 'O'), ('offensive', 'NN', 'O'), ('against', 'IN', 'O')],
#  [('offensive', 'NN', 'O'), ('against', 'IN', 'O'), ('al', 'NNP', 'B-org')],
#  [('against', 'IN', 'O'), ('al', 'NNP', 'B-org'), ('qaida', 'NNP', 'I-org')],
#  [('al', 'NNP', 'B-org'), ('qaida', 'NNP', 'I-org'), ('in', 'IN', 'I-org')],
#  [('qaida', 'NNP', 'I-org'), ('in', 'IN', 'I-org'), ('iraq', 'NNP', 'I-org')],
#  [('in', 'IN', 'I-org'), ('iraq', 'NNP', 'I-org'), ('fighters', 'NNS', 'O')],
#  [('iraq', 'NNP', 'I-org'),
#   ('fighters', 'NNS', 'O'),
#   ('officials', 'NNS', 'O')],
#  [('fighters', 'NNS', 'O'), ('officials', 'NNS', 'O'), ('will', 'MD', 'O')],
#  [('officials', 'NNS', 'O'), ('will', 'MD', 'O'), ('not', 'RB', 'O')],
#  [('will', 'MD', 'O'), ('not', 'RB', 'O'), ('say', 'VB', 'O')],
#  [('not', 'RB', 'O'), ('say', 'VB', 'O'), ('how', 'WRB', 'O')],
#  [('say', 'VB', 'O'), ('how', 'WRB', 'O'), ('many', 'JJ', 'O')],
#  [('how', 'WRB', 'O'), ('many', 'JJ', 'O'), ('troops', 'NNS', 'O')],
#  [('many', 'JJ', 'O'), ('troops', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('troops', 'NNS', 'O'), ('have', 'VBP', 'O'), ('arrived', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('arrived', 'VBN', 'O'), ('in', 'IN', 'O')],
#  [('arrived', 'VBN', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('sunni', 'NNP', 'B-geo')],
#  [('the', 'DT', 'O'), ('sunni', 'NNP', 'B-geo'), ('arab', 'NNP', 'I-geo')],
#  [('sunni', 'NNP', 'B-geo'), ('arab', 'NNP', 'I-geo'), ('and', 'CC', 'O')],
#  [('arab', 'NNP', 'I-geo'), ('and', 'CC', 'O'), ('kurdish', 'NNP', 'B-geo')],
#  [('and', 'CC', 'O'), ('kurdish', 'NNP', 'B-geo'), ('city', 'NN', 'O')],
#  [('kurdish', 'NNP', 'B-geo'), ('city', 'NN', 'O'), ('where', 'WRB', 'O')],
#  [('city', 'NN', 'O'), ('where', 'WRB', 'O'), ('bombings', 'NNS', 'O')],
#  [('where', 'WRB', 'O'), ('bombings', 'NNS', 'O'), ('last', 'JJ', 'O')],
#  [('bombings', 'NNS', 'O'), ('last', 'JJ', 'O'), ('week', 'NN', 'O')],
#  [('last', 'JJ', 'O'), ('week', 'NN', 'O'), ('killed', 'VBD', 'O')],
#  [('week', 'NN', 'O'), ('killed', 'VBD', 'O'), ('at', 'IN', 'O')],
#  [('killed', 'VBD', 'O'), ('at', 'IN', 'O'), ('least', 'JJS', 'O')],
#  [('at', 'IN', 'O'), ('least', 'JJS', 'O'), ('34', 'CD', 'O')],
#  [('least', 'JJS', 'O'), ('34', 'CD', 'O'), ('people', 'NNS', 'O')],
#  [('34', 'CD', 'O'), ('people', 'NNS', 'O'), ('and', 'CC', 'O')],
#  [('people', 'NNS', 'O'), ('and', 'CC', 'O'), ('wounded', 'VBD', 'O')],
#  [('and', 'CC', 'O'), ('wounded', 'VBD', 'O'), ('more', 'JJR', 'O')],
#  [('wounded', 'VBD', 'O'), ('more', 'JJR', 'O'), ('than', 'IN', 'O')],
#  [('more', 'JJR', 'O'), ('than', 'IN', 'O'), ('200', 'CD', 'O')],
#  [('than', 'IN', 'O'), ('200', 'CD', 'O'), ('u.s.', 'NNP', 'B-gpe')],
#  [('200', 'CD', 'O'), ('u.s.', 'NNP', 'B-gpe'), ('commanders', 'NNS', 'O')],
#  [('u.s.', 'NNP', 'B-gpe'), ('commanders', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('commanders', 'NNS', 'O'), ('have', 'VBP', 'O'), ('not', 'RB', 'O')],
#  [('have', 'VBP', 'O'), ('not', 'RB', 'O'), ('explained', 'VBN', 'O')],
#  [('not', 'RB', 'O'), ('explained', 'VBN', 'O'), ('how', 'WRB', 'O')],
#  [('explained', 'VBN', 'O'), ('how', 'WRB', 'O'), ('american', 'JJ', 'B-gpe')],
#  [('how', 'WRB', 'O'), ('american', 'JJ', 'B-gpe'), ('forces', 'NNS', 'O')],
#  [('american', 'JJ', 'B-gpe'), ('forces', 'NNS', 'O'), ('will', 'MD', 'O')],
#  [('forces', 'NNS', 'O'), ('will', 'MD', 'O'), ('participate', 'VB', 'O')],
#  [('will', 'MD', 'O'), ('participate', 'VB', 'O'), ('in', 'IN', 'O')],
#  [('participate', 'VB', 'O'), ('in', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('in', 'IN', 'O'), ('the', 'DT', 'O'), ('offensive', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('offensive', 'NN', 'O'), ('officials', 'NNS', 'O')],
#  [('offensive', 'NN', 'O'), ('officials', 'NNS', 'O'), ('say', 'VBP', 'O')],
#  [('officials', 'NNS', 'O'), ('say', 'VBP', 'O'), ('al', 'NNP', 'B-org')],
#  [('say', 'VBP', 'O'), ('al', 'NNP', 'B-org'), ('qaida', 'NNP', 'I-org')],
#  [('al', 'NNP', 'B-org'), ('qaida', 'NNP', 'I-org'), ('in', 'IN', 'I-org')],
#  [('qaida', 'NNP', 'I-org'), ('in', 'IN', 'I-org'), ('iraq', 'NNP', 'I-org')],
#  [('in', 'IN', 'I-org'), ('iraq', 'NNP', 'I-org'), ('fighters', 'NNS', 'O')],
#  [('iraq', 'NNP', 'I-org'), ('fighters', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('fighters', 'NNS', 'O'), ('have', 'VBP', 'O'), ('fled', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('fled', 'VBN', 'O'), ('successful', 'JJ', 'O')],
#  [('fled', 'VBN', 'O'), ('successful', 'JJ', 'O'), ('campaigns', 'NNS', 'O')],
#  [('successful', 'JJ', 'O'),
#   ('campaigns', 'NNS', 'O'),
#   ('against', 'IN', 'O')],
#  [('campaigns', 'NNS', 'O'), ('against', 'IN', 'O'), ('them', 'PRP', 'O')],
#  [('against', 'IN', 'O'), ('them', 'PRP', 'O'), ('in', 'IN', 'O')],
#  [('them', 'PRP', 'O'), ('in', 'IN', 'O'), ('anbar', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('anbar', 'NNP', 'B-geo'), ('province', 'NN', 'O')],
#  [('anbar', 'NNP', 'B-geo'), ('province', 'NN', 'O'), ('and', 'CC', 'O')],
#  [('province', 'NN', 'O'), ('and', 'CC', 'O'), ('baghdad', 'NNP', 'B-geo')],
#  [('and', 'CC', 'O'), ('baghdad', 'NNP', 'B-geo'), ('to', 'TO', 'O')],
#  [('baghdad', 'NNP', 'B-geo'), ('to', 'TO', 'O'), ('other', 'JJ', 'O')],
#  [('to', 'TO', 'O'), ('other', 'JJ', 'O'), ('northern', 'JJ', 'O')],
#  [('other', 'JJ', 'O'), ('northern', 'JJ', 'O'), ('provinces', 'NNS', 'O')],
#  [('northern', 'JJ', 'O'),
#   ('provinces', 'NNS', 'O'),
#   ('mosul', 'NNP', 'B-geo')],
#  [('provinces', 'NNS', 'O'), ('mosul', 'NNP', 'B-geo'), ('is', 'VBZ', 'O')],
#  [('mosul', 'NNP', 'B-geo'), ('is', 'VBZ', 'O'), ('the', 'DT', 'O')],
#  [('is', 'VBZ', 'O'), ('the', 'DT', 'O'), ('largest', 'JJS', 'O')],
#  [('the', 'DT', 'O'), ('largest', 'JJS', 'O'), ('city', 'NN', 'O')],
#  [('largest', 'JJS', 'O'), ('city', 'NN', 'O'), ('north', 'NN', 'O')],
#  [('city', 'NN', 'O'), ('north', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('north', 'NN', 'O'), ('of', 'IN', 'O'), ('baghdad', 'NNP', 'B-geo')],
#  [('of', 'IN', 'O'), ('baghdad', 'NNP', 'B-geo'), ('and', 'CC', 'O')],
#  [('baghdad', 'NNP', 'B-geo'), ('and', 'CC', 'O'), ('has', 'VBZ', 'O')],
#  [('and', 'CC', 'O'), ('has', 'VBZ', 'O'), ('long', 'RB', 'O')],
#  [('has', 'VBZ', 'O'), ('long', 'RB', 'O'), ('been', 'VBN', 'O')],
#  [('long', 'RB', 'O'), ('been', 'VBN', 'O'), ('a', 'DT', 'O')],
#  [('been', 'VBN', 'O'), ('a', 'DT', 'O'), ('stronghold', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('stronghold', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('stronghold', 'NN', 'O'), ('of', 'IN', 'O'), ('sunni', 'NNP', 'B-org')],
#  [('of', 'IN', 'O'), ('sunni', 'NNP', 'B-org'), ('militant', 'JJ', 'O')],
#  [('sunni', 'NNP', 'B-org'),
#   ('militant', 'JJ', 'O'),
#   ('fighters', 'NNS', 'O')],
#  [('militant', 'JJ', 'O'), ('fighters', 'NNS', 'O'), ('in', 'IN', 'O')],
#  [('fighters', 'NNS', 'O'), ('in', 'IN', 'O'), ('other', 'JJ', 'O')],
#  [('in', 'IN', 'O'), ('other', 'JJ', 'O'), ('violence', 'NN', 'O')],
#  [('other', 'JJ', 'O'), ('violence', 'NN', 'O'), ('u.s.', 'NNP', 'B-gpe')],
#  [('violence', 'NN', 'O'),
#   ('u.s.', 'NNP', 'B-gpe'),
#   ('officials', 'NNS', 'O')],
#  [('u.s.', 'NNP', 'B-gpe'), ('officials', 'NNS', 'O'), ('said', 'VBD', 'O')],
#  [('officials', 'NNS', 'O'), ('said', 'VBD', 'O'), ('one', 'CD', 'O')],
#  [('said', 'VBD', 'O'), ('one', 'CD', 'O'), ('american', 'JJ', 'B-gpe')],
#  [('one', 'CD', 'O'), ('american', 'JJ', 'B-gpe'), ('soldier', 'NN', 'O')],
#  [('american', 'JJ', 'B-gpe'), ('soldier', 'NN', 'O'), ('was', 'VBD', 'O')],
#  [('soldier', 'NN', 'O'), ('was', 'VBD', 'O'), ('killed', 'VBN', 'O')],
#  [('was', 'VBD', 'O'), ('killed', 'VBN', 'O'), ('while', 'IN', 'O')],
#  [('killed', 'VBN', 'O'), ('while', 'IN', 'O'), ('on', 'IN', 'O')],
#  [('while', 'IN', 'O'), ('on', 'IN', 'O'), ('patrol', 'NN', 'O')],
#  [('on', 'IN', 'O'), ('patrol', 'NN', 'O'), ('in', 'IN', 'O')],
#  [('patrol', 'NN', 'O'), ('in', 'IN', 'O'), ('baghdad', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('baghdad', 'NNP', 'B-geo'), ('sunday', 'NNP', 'B-tim')],
#  [('baghdad', 'NNP', 'B-geo'),
#   ('sunday', 'NNP', 'B-tim'),
#   ('egyptian', 'JJ', 'B-gpe')],
#  [('sunday', 'NNP', 'B-tim'),
#   ('egyptian', 'JJ', 'B-gpe'),
#   ('police', 'NNS', 'O')],
#  [('egyptian', 'JJ', 'B-gpe'), ('police', 'NNS', 'O'), ('have', 'VBP', 'O')],
#  [('police', 'NNS', 'O'), ('have', 'VBP', 'O'), ('arrested', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('arrested', 'VBN', 'O'), ('at', 'IN', 'O')],
#  [('arrested', 'VBN', 'O'), ('at', 'IN', 'O'), ('least', 'JJS', 'O')],
#  [('at', 'IN', 'O'), ('least', 'JJS', 'O'), ('16', 'CD', 'O')],
#  [('least', 'JJS', 'O'), ('16', 'CD', 'O'), ('members', 'NNS', 'O')],
#  [('16', 'CD', 'O'), ('members', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('members', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('opposition', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('opposition', 'NN', 'O'), ('muslim', 'NNP', 'B-org')],
#  [('opposition', 'NN', 'O'),
#   ('muslim', 'NNP', 'B-org'),
#   ('brotherhood', 'NNP', 'I-org')],
#  [('muslim', 'NNP', 'B-org'),
#   ('brotherhood', 'NNP', 'I-org'),
#   ('as', 'IN', 'O')],
#  [('brotherhood', 'NNP', 'I-org'), ('as', 'IN', 'O'), ('parts', 'NNS', 'O')],
#  [('as', 'IN', 'O'), ('parts', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('parts', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('country', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('country', 'NN', 'O'), ('prepare', 'VB', 'O')],
#  [('country', 'NN', 'O'), ('prepare', 'VB', 'O'), ('for', 'IN', 'O')],
#  [('prepare', 'VB', 'O'), ('for', 'IN', 'O'), ('parliamentary', 'JJ', 'O')],
#  [('for', 'IN', 'O'), ('parliamentary', 'JJ', 'O'), ('runoff', 'NN', 'O')],
#  [('parliamentary', 'JJ', 'O'),
#   ('runoff', 'NN', 'O'),
#   ('elections', 'NNS', 'O')],
#  [('runoff', 'NN', 'O'),
#   ('elections', 'NNS', 'O'),
#   ('saturday', 'NNP', 'B-tim')],
#  [('elections', 'NNS', 'O'), ('saturday', 'NNP', 'B-tim'), ('the', 'DT', 'O')],
#  [('saturday', 'NNP', 'B-tim'), ('the', 'DT', 'O'), ('arrests', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('arrests', 'NNS', 'O'), ('occurred', 'VBD', 'O')],
#  [('arrests', 'NNS', 'O'),
#   ('occurred', 'VBD', 'O'),
#   ('friday', 'NNP', 'B-tim')],
#  [('occurred', 'VBD', 'O'), ('friday', 'NNP', 'B-tim'), ('in', 'IN', 'O')],
#  [('friday', 'NNP', 'B-tim'),
#   ('in', 'IN', 'O'),
#   ('alexandria', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('alexandria', 'NNP', 'B-geo'), ('a', 'DT', 'O')],
#  [('alexandria', 'NNP', 'B-geo'), ('a', 'DT', 'O'), ('spokesman', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('spokesman', 'NN', 'O'), ('for', 'IN', 'O')],
#  [('spokesman', 'NN', 'O'), ('for', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('for', 'IN', 'O'), ('the', 'DT', 'O'), ('brotherhood', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('brotherhood', 'NNP', 'B-org'), ('said', 'VBD', 'O')],
#  [('brotherhood', 'NNP', 'B-org'), ('said', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('said', 'VBD', 'O'), ('the', 'DT', 'O'), ('arrests', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('arrests', 'NNS', 'O'), ('are', 'VBP', 'O')],
#  [('arrests', 'NNS', 'O'), ('are', 'VBP', 'O'), ('an', 'DT', 'O')],
#  [('are', 'VBP', 'O'), ('an', 'DT', 'O'), ('attempt', 'NN', 'O')],
#  [('an', 'DT', 'O'), ('attempt', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('attempt', 'NN', 'O'), ('to', 'TO', 'O'), ('cut', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('cut', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('cut', 'VB', 'O'), ('the', 'DT', 'O'), ('brotherhood', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('brotherhood', 'NNP', 'B-org'), ('off', 'RB', 'O')],
#  [('brotherhood', 'NNP', 'B-org'), ('off', 'RB', 'O'), ('from', 'IN', 'O')],
#  [('off', 'RB', 'O'), ('from', 'IN', 'O'), ('its', 'PRP$', 'O')],
#  [('from', 'IN', 'O'), ('its', 'PRP$', 'O'), ('supporters', 'NNS', 'O')],
# ...
#  [('majlis-e-amal', 'NNP', 'I-org'),
#   ('dominates', 'VBZ', 'O'),
#   ('the', 'DT', 'O')],
#  [('dominates', 'VBZ', 'O'), ('the', 'DT', 'O'), ('provincial', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('provincial', 'JJ', 'O'), ('assembly', 'NN', 'O')],
#  [('provincial', 'JJ', 'O'), ('assembly', 'NN', 'O'), ('so', 'IN', 'O')],
#  [('assembly', 'NN', 'O'), ('so', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('so', 'IN', 'O'), ('the', 'DT', 'O'), ('bill', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('bill', 'NN', 'O'), ('was', 'VBD', 'O')],
#  [('bill', 'NN', 'O'), ('was', 'VBD', 'O'), ('easily', 'RB', 'O')],
#  [('was', 'VBD', 'O'), ('easily', 'RB', 'O'), ('passed', 'VBN', 'O')],
#  [('easily', 'RB', 'O'), ('passed', 'VBN', 'O'), ('thursday', 'NNP', 'B-tim')],
#  [('passed', 'VBN', 'O'), ('thursday', 'NNP', 'B-tim'), ('by', 'IN', 'O')],
#  [('thursday', 'NNP', 'B-tim'), ('by', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('by', 'IN', 'O'), ('a', 'DT', 'O'), ('vote', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('vote', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('vote', 'NN', 'O'), ('of', 'IN', 'O'), ('68-34', 'CD', 'O')],
#  [('of', 'IN', 'O'), ('68-34', 'CD', 'O'), ('the', 'DT', 'O')],
#  [('68-34', 'CD', 'O'), ('the', 'DT', 'O'), ('provincial', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('provincial', 'JJ', 'O'), ('governor', 'NN', 'O')],
#  [('provincial', 'JJ', 'O'), ('governor', 'NN', 'O'), ('must', 'MD', 'O')],
#  [('governor', 'NN', 'O'), ('must', 'MD', 'O'), ('still', 'RB', 'O')],
#  [('must', 'MD', 'O'), ('still', 'RB', 'O'), ('sign', 'VB', 'O')],
#  [('still', 'RB', 'O'), ('sign', 'VB', 'O'), ('the', 'DT', 'O')],
#  [('sign', 'VB', 'O'), ('the', 'DT', 'O'), ('bill', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('bill', 'NN', 'O'), ('before', 'IN', 'O')],
#  [('bill', 'NN', 'O'), ('before', 'IN', 'O'), ('it', 'PRP', 'O')],
#  [('before', 'IN', 'O'), ('it', 'PRP', 'O'), ('becomes', 'VBZ', 'O')],
#  [('it', 'PRP', 'O'), ('becomes', 'VBZ', 'O'), ('law', 'NN', 'O')],
#  [('becomes', 'VBZ', 'O'), ('law', 'NN', 'O'), ('a', 'DT', 'O')],
#  [('law', 'NN', 'O'), ('a', 'DT', 'O'), ('step', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('step', 'NN', 'O'), ('seen', 'VBN', 'O')],
#  [('step', 'NN', 'O'), ('seen', 'VBN', 'O'), ('only', 'RB', 'O')],
#  [('seen', 'VBN', 'O'), ('only', 'RB', 'O'), ('as', 'IN', 'O')],
#  [('only', 'RB', 'O'), ('as', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('as', 'IN', 'O'), ('a', 'DT', 'O'), ('formality', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('formality', 'NN', 'O'), ('the', 'DT', 'O')],
#  [('formality', 'NN', 'O'), ('the', 'DT', 'O'), ('proposed', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('proposed', 'JJ', 'O'), ('law', 'NN', 'O')],
#  [('proposed', 'JJ', 'O'), ('law', 'NN', 'O'), ('calls', 'VBZ', 'O')],
#  [('law', 'NN', 'O'), ('calls', 'VBZ', 'O'), ('for', 'IN', 'O')],
#  [('calls', 'VBZ', 'O'), ('for', 'IN', 'O'), ('setting', 'VBG', 'O')],
#  [('for', 'IN', 'O'), ('setting', 'VBG', 'O'), ('up', 'RP', 'O')],
#  [('setting', 'VBG', 'O'), ('up', 'RP', 'O'), ('a', 'DT', 'O')],
#  [('up', 'RP', 'O'), ('a', 'DT', 'O'), ('religious', 'JJ', 'O')],
#  [('a', 'DT', 'O'), ('religious', 'JJ', 'O'), ('police', 'NN', 'O')],
#  [('religious', 'JJ', 'O'), ('police', 'NN', 'O'), ('force', 'NN', 'O')],
#  [('police', 'NN', 'O'), ('force', 'NN', 'O'), ('to', 'TO', 'O')],
#  [('force', 'NN', 'O'), ('to', 'TO', 'O'), ('make', 'VB', 'O')],
#  [('to', 'TO', 'O'), ('make', 'VB', 'O'), ('sure', 'JJ', 'O')],
#  [('make', 'VB', 'O'), ('sure', 'JJ', 'O'), ('people', 'NNS', 'O')],
#  [('sure', 'JJ', 'O'), ('people', 'NNS', 'O'), ('adhere', 'VBP', 'O')],
#  [('people', 'NNS', 'O'), ('adhere', 'VBP', 'O'), ('to', 'TO', 'O')],
#  [('adhere', 'VBP', 'O'), ('to', 'TO', 'O'), ('islamic', 'JJ', 'O')],
#  [('to', 'TO', 'O'), ('islamic', 'JJ', 'O'), ('values', 'NNS', 'O')],
#  [('islamic', 'JJ', 'O'), ('values', 'NNS', 'O'), ('in', 'IN', 'O')],
#  [('values', 'NNS', 'O'), ('in', 'IN', 'O'), ('public', 'JJ', 'O')],
#  [('in', 'IN', 'O'), ('public', 'JJ', 'O'), ('places', 'NNS', 'O')],
#  [('public', 'JJ', 'O'), ('places', 'NNS', 'O'), ('and', 'CC', 'O')],
#  [('places', 'NNS', 'O'), ('and', 'CC', 'O'), ('entertainment', 'NN', 'O')],
#  [('and', 'CC', 'O'), ('entertainment', 'NN', 'O'), ('outlets', 'NNS', 'O')],
#  [('entertainment', 'NN', 'O'), ('outlets', 'NNS', 'O'), ('close', 'RB', 'O')],
#  [('outlets', 'NNS', 'O'), ('close', 'RB', 'O'), ('during', 'IN', 'O')],
#  [('close', 'RB', 'O'), ('during', 'IN', 'O'), ('weekly', 'JJ', 'O')],
#  [('during', 'IN', 'O'), ('weekly', 'JJ', 'O'), ('friday', 'NNP', 'B-tim')],
#  [('weekly', 'JJ', 'O'), ('friday', 'NNP', 'B-tim'), ('prayers', 'NNS', 'O')],
#  [('friday', 'NNP', 'B-tim'),
#   ('prayers', 'NNS', 'O'),
#   ('violators', 'NNS', 'O')],
#  [('prayers', 'NNS', 'O'), ('violators', 'NNS', 'O'), ('could', 'MD', 'O')],
#  [('violators', 'NNS', 'O'), ('could', 'MD', 'O'), ('be', 'VB', 'O')],
#  [('could', 'MD', 'O'), ('be', 'VB', 'O'), ('jailed', 'VBN', 'O')],
#  [('be', 'VB', 'O'), ('jailed', 'VBN', 'O'), ('for', 'IN', 'O')],
#  [('jailed', 'VBN', 'O'), ('for', 'IN', 'O'), ('up', 'RB', 'O')],
#  [('for', 'IN', 'O'), ('up', 'RB', 'O'), ('to', 'TO', 'O')],
#  [('up', 'RB', 'O'), ('to', 'TO', 'O'), ('six', 'CD', 'O')],
#  [('to', 'TO', 'O'), ('six', 'CD', 'O'), ('months', 'NNS', 'O')],
#  [('six', 'CD', 'O'), ('months', 'NNS', 'O'), ('the', 'DT', 'O')],
#  [('months', 'NNS', 'O'), ('the', 'DT', 'O'), ('opposition', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('opposition', 'NN', 'O'), ('has', 'VBZ', 'O')],
#  [('opposition', 'NN', 'O'), ('has', 'VBZ', 'O'), ('denounced', 'VBN', 'O')],
#  [('has', 'VBZ', 'O'), ('denounced', 'VBN', 'O'), ('the', 'DT', 'O')],
#  [('denounced', 'VBN', 'O'), ('the', 'DT', 'O'), ('measure', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('measure', 'NN', 'O'), ('comparing', 'VBG', 'O')],
#  [('measure', 'NN', 'O'), ('comparing', 'VBG', 'O'), ('it', 'PRP', 'O')],
#  [('comparing', 'VBG', 'O'), ('it', 'PRP', 'O'), ('to', 'TO', 'O')],
#  [('it', 'PRP', 'O'), ('to', 'TO', 'O'), ('the', 'DT', 'O')],
#  [('to', 'TO', 'O'), ('the', 'DT', 'O'), ('draconian', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('draconian', 'JJ', 'O'), ('rule', 'NN', 'O')],
#  [('draconian', 'JJ', 'O'), ('rule', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('rule', 'NN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('the', 'DT', 'O'), ('former', 'JJ', 'O')],
#  [('the', 'DT', 'O'), ('former', 'JJ', 'O'), ('taleban', 'NNP', 'B-org')],
#  [('former', 'JJ', 'O'), ('taleban', 'NNP', 'B-org'), ('in', 'IN', 'O')],
#  [('taleban', 'NNP', 'B-org'), ('in', 'IN', 'O'), ('neighboring', 'VBG', 'O')],
#  [('in', 'IN', 'O'),
#   ('neighboring', 'VBG', 'O'),
#   ('afghanistan', 'NNP', 'B-geo')],
#  [('neighboring', 'VBG', 'O'),
#   ('afghanistan', 'NNP', 'B-geo'),
#   ('british', 'JJ', 'B-gpe')],
#  [('afghanistan', 'NNP', 'B-geo'),
#   ('british', 'JJ', 'B-gpe'),
#   ('police', 'NNS', 'O')],
#  [('british', 'JJ', 'B-gpe'), ('police', 'NNS', 'O'), ('say', 'VBP', 'O')],
#  [('police', 'NNS', 'O'), ('say', 'VBP', 'O'), ('they', 'PRP', 'O')],
#  [('say', 'VBP', 'O'), ('they', 'PRP', 'O'), ('have', 'VBP', 'O')],
#  [('they', 'PRP', 'O'), ('have', 'VBP', 'O'), ('arrested', 'VBN', 'O')],
#  [('have', 'VBP', 'O'), ('arrested', 'VBN', 'O'), ('a', 'DT', 'O')],
#  [('arrested', 'VBN', 'O'), ('a', 'DT', 'O'), ('man', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('man', 'NN', 'O'), ('who', 'WP', 'O')],
#  [('man', 'NN', 'O'), ('who', 'WP', 'O'), ('dressed', 'VBD', 'O')],
#  [('who', 'WP', 'O'), ('dressed', 'VBD', 'O'), ('as', 'IN', 'O')],
#  [('dressed', 'VBD', 'O'), ('as', 'IN', 'O'), ('suicide', 'NN', 'O')],
#  [('as', 'IN', 'O'), ('suicide', 'NN', 'O'), ('bomber', 'NN', 'O')],
#  [('suicide', 'NN', 'O'), ('bomber', 'NN', 'O'), ('at', 'IN', 'O')],
#  [('bomber', 'NN', 'O'), ('at', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('at', 'IN', 'O'), ('a', 'DT', 'O'), ('demonstration', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('demonstration', 'NN', 'O'), ('against', 'IN', 'O')],
#  [('demonstration', 'NN', 'O'), ('against', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('against', 'IN', 'O'), ('the', 'DT', 'O'), ('publication', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('publication', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('publication', 'NN', 'O'), ('of', 'IN', 'O'), ('cartoons', 'NNS', 'O')],
#  [('of', 'IN', 'O'), ('cartoons', 'NNS', 'O'), ('depicting', 'VBG', 'O')],
#  [('cartoons', 'NNS', 'O'),
#   ('depicting', 'VBG', 'O'),
#   ('islam', 'NNP', 'B-org')],
#  [('depicting', 'VBG', 'O'), ('islam', 'NNP', 'B-org'), ("'s", 'POS', 'O')],
#  [('islam', 'NNP', 'B-org'), ("'s", 'POS', 'O'), ('prophet', 'NNP', 'B-per')],
#  [("'s", 'POS', 'O'),
#   ('prophet', 'NNP', 'B-per'),
#   ('muhammad', 'NNP', 'I-per')],
#  [('prophet', 'NNP', 'B-per'),
#   ('muhammad', 'NNP', 'I-per'),
#   ('bedfordshire', 'NNP', 'B-gpe')],
#  [('muhammad', 'NNP', 'I-per'),
#   ('bedfordshire', 'NNP', 'B-gpe'),
#   ('police', 'NNS', 'O')],
#  [('bedfordshire', 'NNP', 'B-gpe'),
#   ('police', 'NNS', 'O'),
#   ('said', 'VBD', 'O')],
#  [('police', 'NNS', 'O'), ('said', 'VBD', 'O'), ('tuesday', 'NNP', 'B-tim')],
#  [('said', 'VBD', 'O'), ('tuesday', 'NNP', 'B-tim'), ('that', 'IN', 'O')],
#  [('tuesday', 'NNP', 'B-tim'), ('that', 'IN', 'O'), ('omar', 'NNP', 'B-per')],
#  [('that', 'IN', 'O'), ('omar', 'NNP', 'B-per'), ('khayam', 'NNP', 'I-per')],
#  [('omar', 'NNP', 'B-per'), ('khayam', 'NNP', 'I-per'), ('was', 'VBD', 'O')],
#  [('khayam', 'NNP', 'I-per'), ('was', 'VBD', 'O'), ('arrested', 'VBN', 'O')],
#  [('was', 'VBD', 'O'), ('arrested', 'VBN', 'O'), ('in', 'IN', 'O')],
#  [('arrested', 'VBN', 'O'), ('in', 'IN', 'O'), ('bedford', 'NNP', 'B-geo')],
#  [('in', 'IN', 'O'), ('bedford', 'NNP', 'B-geo'), ('for', 'IN', 'O')],
#  [('bedford', 'NNP', 'B-geo'), ('for', 'IN', 'O'), ('breaching', 'VBG', 'O')],
#  [('for', 'IN', 'O'), ('breaching', 'VBG', 'O'), ('the', 'DT', 'O')],
#  [('breaching', 'VBG', 'O'), ('the', 'DT', 'O'), ('conditions', 'NNS', 'O')],
#  [('the', 'DT', 'O'), ('conditions', 'NNS', 'O'), ('of', 'IN', 'O')],
#  [('conditions', 'NNS', 'O'), ('of', 'IN', 'O'), ('his', 'PRP$', 'O')],
#  [('of', 'IN', 'O'), ('his', 'PRP$', 'O'), ('parole', 'NN', 'O')],
#  [('his', 'PRP$', 'O'), ('parole', 'NN', 'O'), ('police', 'NNS', 'O')],
#  [('parole', 'NN', 'O'), ('police', 'NNS', 'O'), ('said', 'VBD', 'O')],
#  [('police', 'NNS', 'O'), ('said', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('said', 'VBD', 'O'), ('the', 'DT', 'O'), ('british', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('british', 'NNP', 'B-org'), ('home', 'NNP', 'I-org')],
#  [('british', 'NNP', 'B-org'),
#   ('home', 'NNP', 'I-org'),
#   ('office', 'NNP', 'I-org')],
#  [('home', 'NNP', 'I-org'),
#   ('office', 'NNP', 'I-org'),
#   ('sought', 'VBD', 'O')],
#  [('office', 'NNP', 'I-org'), ('sought', 'VBD', 'O'), ('an', 'DT', 'O')],
#  [('sought', 'VBD', 'O'), ('an', 'DT', 'O'), ('investigation', 'NN', 'O')],
#  [('an', 'DT', 'O'), ('investigation', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('investigation', 'NN', 'O'), ('of', 'IN', 'O'), ('khayam', 'NNP', 'B-per')],
#  [('of', 'IN', 'O'), ('khayam', 'NNP', 'B-per'), ("'s", 'POS', 'O')],
#  [('khayam', 'NNP', 'B-per'), ("'s", 'POS', 'O'), ('behavior', 'NN', 'O')],
#  [("'s", 'POS', 'O'), ('behavior', 'NN', 'O'), ('after', 'IN', 'O')],
#  [('behavior', 'NN', 'O'), ('after', 'IN', 'O'), ('he', 'PRP', 'O')],
#  [('after', 'IN', 'O'), ('he', 'PRP', 'O'), ('was', 'VBD', 'O')],
#  [('he', 'PRP', 'O'), ('was', 'VBD', 'O'), ('photographed', 'VBN', 'O')],
#  [('was', 'VBD', 'O'), ('photographed', 'VBN', 'O'), ('last', 'JJ', 'O')],
#  [('photographed', 'VBN', 'O'), ('last', 'JJ', 'O'), ('week', 'NN', 'O')],
#  [('last', 'JJ', 'O'), ('week', 'NN', 'O'), ('at', 'IN', 'O')],
#  [('week', 'NN', 'O'), ('at', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('at', 'IN', 'O'), ('a', 'DT', 'O'), ('demonstration', 'NN', 'O')],
#  [('a', 'DT', 'O'), ('demonstration', 'NN', 'O'), ('dressed', 'VBN', 'O')],
#  [('demonstration', 'NN', 'O'), ('dressed', 'VBN', 'O'), ('in', 'IN', 'O')],
#  [('dressed', 'VBN', 'O'), ('in', 'IN', 'O'), ('fatigues', 'NNS', 'O')],
#  [('in', 'IN', 'O'), ('fatigues', 'NNS', 'O'), ('a', 'DT', 'O')],
#  [('fatigues', 'NNS', 'O'), ('a', 'DT', 'O'), ('black', 'JJ', 'O')],
#  [('a', 'DT', 'O'), ('black', 'JJ', 'O'), ('cap', 'NN', 'O')],
#  [('black', 'JJ', 'O'), ('cap', 'NN', 'O'), ('and', 'CC', 'O')],
#  [('cap', 'NN', 'O'), ('and', 'CC', 'O'), ('a', 'DT', 'O')],
#  [('and', 'CC', 'O'), ('a', 'DT', 'O'), ('bulky', 'JJ', 'O')],
#  [('a', 'DT', 'O'), ('bulky', 'JJ', 'O'), ('belt', 'NN', 'O')],
#  [('bulky', 'JJ', 'O'), ('belt', 'NN', 'O'), ('a', 'DT', 'O')],
#  [('belt', 'NN', 'O'), ('a', 'DT', 'O'), ('home', 'NNP', 'B-org')],
#  [('a', 'DT', 'O'), ('home', 'NNP', 'B-org'), ('office', 'NNP', 'I-org')],
#  [('home', 'NNP', 'B-org'),
#   ('office', 'NNP', 'I-org'),
#   ('spokesman', 'NN', 'O')],
#  [('office', 'NNP', 'I-org'), ('spokesman', 'NN', 'O'), ('told', 'VBD', 'O')],
#  [('spokesman', 'NN', 'O'), ('told', 'VBD', 'O'), ('the', 'DT', 'O')],
#  [('told', 'VBD', 'O'), ('the', 'DT', 'O'), ('associated', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'),
#   ('associated', 'NNP', 'B-org'),
#   ('press', 'NNP', 'I-org')],
#  [('associated', 'NNP', 'B-org'),
#   ('press', 'NNP', 'I-org'),
#   ('that', 'IN', 'O')],
#  [('press', 'NNP', 'I-org'), ('that', 'IN', 'O'), ('if', 'IN', 'O')],
#  [('that', 'IN', 'O'), ('if', 'IN', 'O'), ('the', 'DT', 'O')],
#  [('if', 'IN', 'O'), ('the', 'DT', 'O'), ('behavior', 'NN', 'O')],
#  [('the', 'DT', 'O'), ('behavior', 'NN', 'O'), ('of', 'IN', 'O')],
#  [('behavior', 'NN', 'O'), ('of', 'IN', 'O'), ('a', 'DT', 'O')],
#  [('of', 'IN', 'O'), ('a', 'DT', 'O'), ('paroled', 'JJ', 'O')],
#  [('a', 'DT', 'O'), ('paroled', 'JJ', 'O'), ('offender', 'NN', 'O')],
#  [('paroled', 'JJ', 'O'), ('offender', 'NN', 'O'), ('gives', 'VBZ', 'O')],
#  [('offender', 'NN', 'O'), ('gives', 'VBZ', 'O'), ('cause', 'NN', 'O')],
#  [('gives', 'VBZ', 'O'), ('cause', 'NN', 'O'), ('for', 'IN', 'O')],
#  [('cause', 'NN', 'O'), ('for', 'IN', 'O'), ('concern', 'NN', 'O')],
#  [('for', 'IN', 'O'), ('concern', 'NN', 'O'), ('he', 'PRP', 'O')],
#  [('concern', 'NN', 'O'), ('he', 'PRP', 'O'), ('can', 'MD', 'O')],
#  [('he', 'PRP', 'O'), ('can', 'MD', 'O'), ('be', 'VB', 'O')],
#  [('can', 'MD', 'O'), ('be', 'VB', 'O'), ('sent', 'VBN', 'O')],
#  [('be', 'VB', 'O'), ('sent', 'VBN', 'O'), ('back', 'RB', 'O')],
#  [('sent', 'VBN', 'O'), ('back', 'RB', 'O'), ('to', 'TO', 'O')],
#  [('back', 'RB', 'O'), ('to', 'TO', 'O'), ('prison', 'NN', 'O')],
#  [('to', 'TO', 'O'), ('prison', 'NN', 'O'), ('the', 'DT', 'O')],
#  [('prison', 'NN', 'O'), ('the', 'DT', 'O'), ('ap', 'NNP', 'B-org')],
#  [('the', 'DT', 'O'), ('ap', 'NNP', 'B-org'), ('also', 'RB', 'O')],
#  [('ap', 'NNP', 'B-org'), ('also', 'RB', 'O'), ('reports', 'VBZ', 'O')],
#  [('also', 'RB', 'O'), ('reports', 'VBZ', 'O'), ('khayam', 'NNP', 'B-per')],
#  [('reports', 'VBZ', 'O'), ('khayam', 'NNP', 'B-per'), ('has', 'VBZ', 'O')],
#  [('khayam', 'NNP', 'B-per'), ('has', 'VBZ', 'O'), ('been', 'VBN', 'O')],
#  [('has', 'VBZ', 'O'), ('been', 'VBN', 'O'), ('on', 'IN', 'O')],
#  [('been', 'VBN', 'O'), ('on', 'IN', 'O'), ('parole', 'NN', 'O')],
#  [('on', 'IN', 'O'), ('parole', 'NN', 'O'), ('from', 'IN', 'O')],
#  [('parole', 'NN', 'O'), ('from', 'IN', 'O'), ('prison', 'NN', 'O')],
#  [('from', 'IN', 'O'), ('prison', 'NN', 'O'), ('since', 'IN', 'O')],
#  [('prison', 'NN', 'O'), ('since', 'IN', 'O'), ('last', 'JJ', 'O')],
#  [('since', 'IN', 'O'), ('last', 'JJ', 'O'), ('year', 'NN', 'O')],
#  [('last', 'JJ', 'O'), ('year', 'NN', 'O'), ('after', 'IN', 'O')],
#  [('year', 'NN', 'O'), ('after', 'IN', 'O'), ('serving', 'VBG', 'O')],
#  [('after', 'IN', 'O'), ('serving', 'VBG', 'O'), ('half', 'PDT', 'O')],
#  [('serving', 'VBG', 'O'), ('half', 'PDT', 'O'), ('his', 'PRP$', 'O')],
#  [('half', 'PDT', 'O'), ('his', 'PRP$', 'O'), ('six-year', 'JJ', 'O')],
#  [('his', 'PRP$', 'O'), ('six-year', 'JJ', 'O'), ('sentence', 'NN', 'O')],
#  [('six-year', 'JJ', 'O'), ('sentence', 'NN', 'O'), ('for', 'IN', 'O')],
#  [('sentence', 'NN', 'O'), ('for', 'IN', 'O'), ('drug', 'NN', 'O')],
#  [('for', 'IN', 'O'), ('drug', 'NN', 'O'), ('dealing', 'NN', 'O')],
#  [('drug', 'NN', 'O'), ('dealing', 'NN', 'O'), ('pakistani', 'JJ', 'B-gpe')],
#  [('dealing', 'NN', 'O'),
#   ('pakistani', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O')],
#  [('pakistani', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O')],
#  [('officials', 'NNS', 'O'), ('say', 'VBP', 'O'), ('unidentified', 'JJ', 'O')],
#  [('say', 'VBP', 'O'), ('unidentified', 'JJ', 'O'), ('gunmen', 'NNS', 'O')],
#  ...]

# %%
suffixes = []
for item in set(train['Word']):
    suffixes.append(item[-3:])
        
pos_vocab = set(train['POS'])
index_to_pos = {k:v for k, v in enumerate(pos_vocab)}
pos_to_index = {v:k for k, v in index_to_pos.items()}

tag_vocab = set(train['Tag'])
index_to_tag = {k:v for k, v in enumerate(tag_vocab)}
tag_to_index = {v:k for k, v in index_to_tag.items()}

word_vocab = set(train['Word'])
print(len(word_vocab))

word_vocab.update(suffixes)
print(len(word_vocab))

index_to_word = {k+len(pos_vocab): v for k, v in enumerate(word_vocab)}
word_to_index = {v:k for k, v in index_to_word.items()}

print(len(word_vocab), len(pos_vocab), len(tag_vocab))
# Out:
# 31811
# 34764
# 34764 42 17

# %%
def build_features(row):
    features = []
    
    features.append(word_to_index[row[1][0].lower()])
    features.append(word_to_index[row[1][0][-3:]])
#    features.append(row[1][0][-2:])
    features.append(int(row[1][0].istitle()))
    features.append(int(row[1][0].isupper()))    
    features.append(int(row[1][0].isdigit()))    
    features.append(pos_to_index[row[1][1]])
#    features.append(row[1][1][:2])    
    
    
    features.append(word_to_index[row[0][0].lower()])
    features.append(int(row[0][0].istitle()))
    features.append(int(row[0][0].isupper()))   
    features.append(pos_to_index[row[0][1]])
#    features.append(row[0][1][:2])    

    features.append(word_to_index[row[2][0].lower()])
    features.append(int(row[2][0].istitle()))
    features.append(int(row[2][0].isupper()))
    features.append(pos_to_index[row[2][1]])
#    features.append(row[2][1][:2])    

    features.append(tag_to_index[row[1][2]])
    return features
    
feature_extractor(matrix[0])
# Out:
# [11313, 11313, 0, 0, 0, 10, 27804, 0, 0, 29, 28401, 0, 0, 29, 0]

# %%
transformed_matrix = []

for row in matrix:
    features = build_features(row)    
    transformed_matrix.append(features)

# %%
len(transformed_matrix[0])
# Out:
# 15

# %%
def get_model(vocab_size, d_model):

    model = keras.Sequential()
    model.add(layers.Embedding(input_dim=vocab_size, output_dim=d_model, input_length=14))
    model.add(layers.Flatten())
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.Dropout(.1))
    model.add(layers.Dense(len(tag_vocab), activation='sigmoid'))

    return model

# %%
model = get_model(len(word_vocab)+len(pos_vocab)+len(tag_vocab), 100)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 14, 100)           3482300
# _________________________________________________________________
# flatten (Flatten)            (None, 1400)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               140100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                1717
# =================================================================
# Total params: 3,624,117
# Trainable params: 3,624,117
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(), loss=keras.losses.CategoricalCrossentropy()
              , metrics=[keras.metrics.CategoricalAccuracy()])

# %%
X, y = np.array(transformed_matrix)[:, :-1], keras.utils.to_categorical(np.array(transformed_matrix)[:, -1], num_classes=len(tag_vocab))
X.shape, y.shape
# Out:
# ((960742, 14), (960742, 17))

# %%
max_train_size = 10000
X_train = X[:max_train_size]
X_test = X[max_train_size:max_train_size+int(.1*max_train_size)]

y_train = y[:max_train_size]
y_test = y[max_train_size:max_train_size+int(.1*max_train_size)]

# %%
history = model.fit(X_train, 
                    y_train, 
                    validation_data=(X_test, y_test), 
                    batch_size=32, 
                    epochs=10, 
                    callbacks=tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy', patience=2))

for key in ['categorical_accuracy', 'val_categorical_accuracy']:
    plt.plot(history.history[key], label=key)
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 313/313 [==============================] - 9s 27ms/step - loss: 0.2881 - categorical_accuracy: 0.9211 - val_loss: 0.1562 - val_categorical_accuracy: 0.9580
# Epoch 2/10
# 313/313 [==============================] - 9s 27ms/step - loss: 0.1301 - categorical_accuracy: 0.9668 - val_loss: 0.1174 - val_categorical_accuracy: 0.9670
# Epoch 3/10
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0686 - categorical_accuracy: 0.9821 - val_loss: 0.1157 - val_categorical_accuracy: 0.9700
# Epoch 4/10
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0374 - categorical_accuracy: 0.9902 - val_loss: 0.1308 - val_categorical_accuracy: 0.9660
# Epoch 5/10
# 313/313 [==============================] - 8s 27ms/step - loss: 0.0213 - categorical_accuracy: 0.9947 - val_loss: 0.1478 - val_categorical_accuracy: 0.9640

# %%
model.save('data/ner_model/')
# Out:
# INFO:tensorflow:Assets written to: data/ner_model/assets

# %%
results = []
for a in range(1000):
    results.append(np.argmax(model.predict(X_test[a].reshape(1,-1)))==np.argmax(y_test[a]))
    if not a%100:
        print(np.mean(results))
# Out:
# 1.0
# 0.9801980198019802
# 0.9751243781094527
# 0.9767441860465116
# 0.9775561097256857
# 0.9700598802395209
# 0.9667221297836939
# 0.9657631954350927
# 0.9675405742821473
# 0.9633740288568258

# %%
it = train[['Word', 'POS', 'Tag']].itertuples(index=False, name=None)
row = []
for a in range (5):
    row.append(next(it))

# %%
row
# Out:
# [('thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O')]

# %%
features = build_features(row)[:-1]
features
# Out:
# [11313, 11313, 0, 0, 0, 10, 27804, 0, 0, 29, 28401, 0, 0, 29]

# %%
prediction = model.predict(np.array(features).reshape(1,-1))
np.argmax(prediction)
# Out:
# 0

# %%
index_to_tag[0]
# Out:
# 'O'

# %%
model = keras.models.load_model('data/ner_model/')
